# %%
import requests as req

# %%
url = 'https://www.kamis.or.kr/customer/main/main.do'
res = req.get(url)

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <title>농산물유통정보:::KAMIS</title>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="농산물, 수산물, 축산물의 품목별 도소매 가격정보 제공. 한국농수산식품유통공사 운영" name="description"/>
# <link href="/common/css/jquery.bxslider.css" rel="stylesheet"/>
# <!--<link rel="stylesheet" href="/css/customer/common.css" />-->
# <link href="/common/css/common.css" rel="stylesheet"/>
# <link href="/common/css/common_new.css" rel="stylesheet"/>
# <script src="/common/js/jquery-3.6.0.js"></script>
# <script src="/js/customer/jquery-ui.js"></script>
# <script src="/js/customer/respond.js"></script>
# <script src="/js/customer/common.js"></script>
# <script src="/js/customer/jsutil.js"></script>
# <script src="/js/customer/circulation/domestic.js"></script>
# <script src="/js/customer/charts/highcharts.js"></script>
# <script src="/js/customer/charts/exporting.js"></script>
# <script src="/js/customer/iteminfo_util_common.js"></script>
# <script src="/common/js/common_new.js"></script>
# <!--[if lt IE 7]>
# 	<script type="text/javascript">//location.href="";</script>
# <![endif]-->
# <!--[if lt IE 9]>
# 	<script type="text/javascript" src="/js/customer/html5shiv.js"></script>
# <![endif]-->
# <script src="/common/js/jquery.bxslider.min.js"></script>
# <script src="/common/js/main_new.js"></script>
# <script src="/js/customer/jquery.slides.min.js"></script>
# <script src="/js/customer/jquery.alsEN-1.0.min.js"></script>
# <script src="/js/popup.js" type="text/javascript"></script>
# <script src="/js/customer/main/main.js" type="text/javascript"></script>
# <link href="/css/popup.css" rel="stylesheet" type="text/css"/>
# <link href="/css/customer/main.css" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# 			//n_so_pid(1);  /* 스크립트를 여러 페이지에 적용할 경우 ( ) 안의 값을 변경 (숫자만 사용가능) */
# 		</script>
# <script type="text/javascript">
# 			var g_resultcode	= '';
# 			var g_resultmessage = '';
#
# 			if (Number(g_resultcode) < 0) {
# 				alert(g_resultmessage);
# 			}
#
# 			function shareSNS(mode) {
# 				var fullUrl;
# 				var param = encodeURIComponent(location.href);
# 				var m = document.getElementsByTagName('meta');
# 				var title = "농산물유통정보 KAMIS";
# 				var description = "";
#
# 				if (mode == 'twitter') {
# 					fullUrl = "https://twitter.com/intent/tweet?text=" + title + "&url=" + param;
# 				} else if (mode == 'facebook') {
# 					fullUrl = "http://www.facebook.com/sharer/sharer.php?u=" + param;
# 				} else {
# 					fullUrl = "https://story.kakao.com/share?url=" + param;
# 				}
#
# 				var pWidth = 640;
# 				var pHeight = 380;
# 				var pLeft = (screen.width - pWidth) / 2;
# 				var pTop = (screen.height - pHeight) / 2;
#
# 				window.open(fullUrl,"","width="+ pWidth +",height="+ pHeight +",left="+ pLeft +",top="+ pTop +",location=no,menubar=no,status=no,scrollbars=no,resizable=no,titlebar=no,toolbar=no");
# 			}
# 		</script>
# <script type="text/javascript">
# 			$(document).ready(function() {
# 				atPopup.getPopupCookie('popupLayer522');
# 				atPopup.getPopupCookie('popupLayer523');
# 				atPopup.getPopupCookie('popupLayer524');
# 			});
#
# 			function movePage() {
# 				//var link = 'https://blog.naver.com/PostList.nhn?blogId=gr22nade&from=postList&categoryNo=82&parentCategoryNo=82#';
# // 				var link ='https://www.youtube.com/watch?v=qPxd_NPrKGc';
# // 				var link = 'https://youtu.be/ihzd4fH1SgI';
# 				var link = 'https://youtu.be/lquR8Tj8FMw';
#
#
# 				window.open(link);
# 			}
# 		</script>
# <style>
# 			.scrolltbody {
# 			    display: block;
# 			    width: 575px;
# 			    border-collapse: collapse;
# 			}
# 			.scrolltbody tr { height:30px !important;}
# 			.scrolltbody th { font-size:13px !important;line-height:0.5 !important;}
# 			.scrolltbody td { font-size:13px !important;line-height:1 !important; font-family : NotoKrL !important;}
# 			.scrolltbody tbody {
# 			    display: block;
# 			    height: 151px;
# 			    overflow: auto;
# 			}
# /* 			.scrolltbody th:nth-of-type(1) { width: 132px; } */
# /* 			.scrolltbody td:nth-of-type(1) { width: 117px; text-align:left; padding-left:10px;} */
# /* 			.scrolltbody th:nth-of-type(2) { width: 73px; } */
# /* 			.scrolltbody td:nth-of-type(2) { width: 90px;} */
# /* 			.scrolltbody th:nth-of-type(3) { width: 77px; } */
# /* 			.scrolltbody td:nth-of-type(3) { width: 62px; text-align:right;} */
# /* 			.scrolltbody th:nth-of-type(4) { width: 96px; } */
# /* 			.scrolltbody td:nth-of-type(4) { width: 70px; } */
# /* 			.scrolltbody th:nth-of-type(5) { width: 65px; } */
# /* 			.scrolltbody td:nth-of-type(5) { width: 58px; text-align:right;} */
# /* 			.scrolltbody th:nth-of-type(6) { width: 88px; } */
# /* 			.scrolltbody td:nth-of-type(6) { width: 76px; text-align:right;} */
# /* 			.scrolltbody th:last-child { width: 70px; padding-right:7px; } */
# /* 			.scrolltbody td:last-child { width: calc( 94px - 19px ); padding-right:5px; text-align:right;} */
#
#
#  			.scrolltbody th:nth-of-type(1) { width: 132px; }
#  			.scrolltbody td:nth-of-type(1) { width: 117px; text-align:left; padding-left:10px;}
#  			.scrolltbody th:nth-of-type(2) { width: 73px; }
#  			.scrolltbody td:nth-of-type(2) { width: 73px;}
#  			.scrolltbody th:nth-of-type(3) { width: 73px; }
#  			.scrolltbody td:nth-of-type(3) { width: 62px; text-align:right;}
#  			.scrolltbody th:nth-of-type(4) { width: 96px; }
#  			.scrolltbody td:nth-of-type(4) { width: 111px; }
#  			.scrolltbody th:nth-of-type(5) { width: 65px; }
#  			.scrolltbody td:nth-of-type(5) { width: 48px; text-align:right;}
#  			.scrolltbody th:nth-of-type(6) { width: 88px; }
#  			.scrolltbody td:nth-of-type(6) { width: 76px; text-align:right;}
#  			.scrolltbody th:last-child { width: 70px; padding-right:7px; }
#  			.scrolltbody td:last-child { width: calc( 94px - 19px ); padding-right:5px; text-align:right;}
# 		</style>
# </head>
# <body>
# <script async="" defer="" src="https://apis.google.com/js/platform.js"></script>
# <script>
# $.browser={};(function(){
# 	jQuery.browser.msie=false;
# 	$.browser.version=0;if(navigator.userAgent.match(/MSIE ([0-9]+)\./)){
# 	$.browser.msie=true;jQuery.browser.version=RegExp.$1;}
# })();
# 	function logout(snsType) {
# 		location.href = "/customer/customer_service/login/sns_login.do?snsType=" + snsType;
# 	}
#
# 	function fnSearch() {
# 		$( ".smartWrap" ).slideToggle( "slow" );
# 	}
#
# 	function naverLogout() {
# 		$("#naverLogoutForm").submit();
# 		location.href = "/customer/customer_service/login/logout.do";
# 	}
# </script>
# <header>
# <section class="logArea">
# <div class="wrap_comn">
# <div class="fl_r">
# <ul>
# <li>
# <a href="https://www.kamis.or.kr/customer/customer_service/login/sns_login.do">로그인</a>
# </li>
# <li>
# <!-- 								<a href="https://www.kamis.or.kr/customer/customer_service/join/customer_sns_join.do?action=snsJoinType">회원가입</a> -->
# <a href="https://www.kamis.or.kr/customer/customer_service/join/customer_sns_join.do?action=snsJoin">회원가입</a>
# </li>
# </ul>
# </div>
# </div> <!--//wrap_comn -->
# </section> <!--//logArea -->
# <section class="smartWrap">
# <section class="smart_search">
# <!-- 검색영역 선택 -->
# <section class="smart_search_nav">
# <div class="on" style="width:356px;">
# <header class="smart_first_on1"><a onclick="searchTop('1');">도매가격</a></header>
# <table class="nav_table">
# <colgroup>
# <col style="width:100px;"/>
# <col/>
# </colgroup>
# <tr>
# <th>품목별</th>
# <td>
# <ul>
# <li class="on smart_first1"><a onclick="searchTop('1');">· 품목별</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>기간별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('2');">· 일간</a></li>
# <li><a onclick="searchTop('3');">· 반순별</a></li>
# <li><a onclick="searchTop('4');">· 순별</a></li>
# <li><a onclick="searchTop('5');">· 월간</a></li>
# <li><a onclick="searchTop('6');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>부류별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('7');">· 일간</a></li>
# <li><a onclick="searchTop('8');">· 월간</a></li>
# <li><a onclick="searchTop('9');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# <div style="width:356px;">
# <header class="smart_first_on2"><a onclick="searchTop('10');">소매가격</a></header>
# <table class="nav_table">
# <colgroup>
# <col style="width:100px;"/>
# <col/>
# </colgroup>
# <tr>
# <th>품목별</th>
# <td>
# <ul>
# <li class="smart_first2"><a onclick="searchTop('10');">· 품목별</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>기간별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('11');">· 일간</a></li>
# <li><a onclick="searchTop('12');">· 반순별</a></li>
# <li><a onclick="searchTop('13');">· 순별</a></li>
# <li><a onclick="searchTop('14');">· 월간</a></li>
# <li><a onclick="searchTop('15');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>부류별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('16');">· 일간</a></li>
# <li><a onclick="searchTop('17');">· 월간</a></li>
# <li><a onclick="searchTop('18');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>시장별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('28');">· 기간별</a></li>
# <li><a onclick="searchTop('31');">· 부류별</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>친환경농산물</th>
# <td>
# <ul>
# <li><a onclick="searchTop('34');">· 품목별</a></li>
# <li><a onclick="searchTop('35');">· 기간별</a></li>
# <li><a onclick="searchTop('36');">· 부류별</a></li>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# <div style="width:356px;">
# <header class="smart_first_on3"><a onclick="searchTop('19');">도·소매가격</a></header>
# <table class="nav_table">
# <colgroup>
# <col style="width:100px;"/>
# <col/>
# </colgroup>
# <tr>
# <th>품목별</th>
# <td>
# <ul>
# <li class="smart_first3"><a onclick="searchTop('19');">· 품목별</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>기간별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('20');">· 일간</a></li>
# <li><a onclick="searchTop('21');">· 반순별</a></li>
# <li><a onclick="searchTop('22');">· 순별</a></li>
# <li><a onclick="searchTop('23');">· 월간</a></li>
# <li><a onclick="searchTop('24');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# <tr>
# <th>부류별</th>
# <td>
# <ul>
# <li><a onclick="searchTop('25');">· 일간</a></li>
# <li><a onclick="searchTop('26');">· 월간</a></li>
# <li><a onclick="searchTop('27');">· 연간</a></li>
# </ul>
# </td>
# </tr>
# </table>
# </div>
# </section>
# <!--// 검색영역 선택 -->
# <!-- 검색세부항목 선택 -->
# <section class="smart_searchWrap type1" id="commonSearchArea">
# <div class="smart_ing searchCommArea" id="X">
# <ul>
# <li class="w2 bg">기간</li>
# <li class="w2 bg">부류</li>
# <li class="w2 bg">품목</li>
# <li class="w2 bg">품종</li>
# <li class="w2">등급</li>
# </ul>
# </div>
# <div class="smart_ing searchCommArea" id="Y" style="display:none;">
# <ul>
# <li class="w1 bg">기간</li>
# <li class="w1 bg">지역</li>
# <li class="w1 bg">부류</li>
# <li class="w1 bg">품목</li>
# <li class="w1 bg">품종</li>
# <li class="w1">등급</li>
# </ul>
# </div>
# <div class="smart_ing searchCommArea" id="Z" style="display:none;">
# <ul>
# <li class="w4 bg">기간</li>
# <li class="w4 bg">지역</li>
# <li class="w4">부류</li>
# </ul>
# </div>
# <div class="smart_cal searchCommArea" id="A">
# <ul class="sc_ns">
# <li class="on">
# <a class="cal_open_btn">날짜 : <input id="regdaycommon" name="regdaycommon" readonly="" style="width:75px;" type="text" value=""/></a>
# <div class="calendarWrap cw_ns1">
# <div class="datepicker" id="regDatepickerComm"></div>
# </div>
# </li>
# </ul>
# </div>
# <div class="smart_cal searchCommArea" id="B" style="display:none;">
# <ul class="sc_ns">
# <li class="on">
# <a class="cal_open_btn">시작일 : <input id="startdaycommon" name="startdaycommon" readonly="" style="width:75px;padding-bottom:3px;" type="text" value=""/></a>
# <div class="calendarWrap cw_ns1">
# <div class="datepicker" id="startDatepickerComm"></div>
# </div>
# </li>
# <li>
# <a class="cal_open_btn">종료일 : <input id="enddaycommon" name="enddaycommon" readonly="" style="width:75px;padding-bottom:3px;" type="text" value=""/></a>
# <div class="calendarWrap cw_ns2">
# <div class="datepicker" id="endDatepickerComm"></div>
# </div>
# </li>
# </ul>
# </div>
# <div class="smart_cal searchCommArea" id="C" style="display:none;">
# <ul>
# <li class="on">
# <a class="cal_open_btn"><input id="viewCyyyy" readonly="" style="width:45px;" type="text" value="2015년"/> <input id="viewCstart_mm" readonly="" style="width:75px;" type="text" value="1월 ~ 3월"/></a>
# <div class="calendarWrap calendarWrap2">
# <select id="yyyyCcommon" name="yyyyCcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewCyyyy')">
# <option value="2014">2014년</option>
# <option value="2015">2015년</option>
# </select>
# <select id="start_mmddcommon" name="start_mmddcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewCstart_mm')">
# <option value="0101">1월 ~ 3월</option>
# <option value="0401">4월 ~ 6월</option>
# <option value="0701">7월 ~ 9월</option>
# <option value="1001">10월 ~ 12월</option>
# </select>
# </div>
# </li>
# </ul>
# </div>
# <div class="smart_cal searchCommArea" id="D" style="display:none;">
# <ul>
# <li class="on">
# <a class="cal_open_btn"><input id="viewDyyyy" readonly="" style="width:45px;" type="text" value="2015년"/> <input id="viewDperiod" readonly="" style="width:40px;" type="text" value="3년간"/></a>
# <div class="calendarWrap calendarWrap2">
# <select id="yyyyDcommon" name="yyyyDcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewDyyyy')">
# <option value="2014">2014년</option>
# <option value="2015">2015년</option>
# </select>
# <select id="periodcommon" name="periodcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewDperiod')">
# <option value="3">3년간</option>
# <option value="5">5년간</option>
# <option value="10">10년간</option>
# <option value="20">전체</option>
# </select>
# </div>
# </li>
# </ul>
# </div>
# <div class="smart_cal searchCommArea" id="E" style="display:none;">
# <ul>
# <li class="on">
# <a class="cal_open_btn"><input id="viewEyyyy" readonly="" style="width:45px;" type="text" value="2015년"/> <input id="viewEmm" readonly="" style="width:40px;" type="text" value="1월"/></a>
# <div class="calendarWrap calendarWrap2">
# <select id="yyyyEcommon" name="yyyyEcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewEyyyy')">
# <option value="2014">2014년</option>
# <option value="2015">2015년</option>
# </select>
# <select id="mmcommon" name="mmcommon" onchange="setSearchBox(this.options[this.selectedIndex].text, 'viewEmm')">
# <option value="01">1월</option>
# <option value="02">2월</option>
# <option value="03">3월</option>
# <option value="04">4월</option>
# <option value="05">5월</option>
# <option value="06">6월</option>
# <option value="07">7월</option>
# <option value="08">8월</option>
# <option value="09">9월</option>
# <option value="10">10월</option>
# <option value="11">11월</option>
# <option value="12">12월</option>
# </select>
# </div>
# </li>
# </ul>
# </div>
# <div class="smart_list searchCommArea" id="G" style="display:none;">
# <ul class="list_ty1 ss1_ns" id="ulcountycodecommon">
# <li class="on"><a onclick="setSearchBox('','countycodecommon')">전체</a></li>
# <li><a onclick="setSearchBox('1101','countycodecommon')">서울</a></li>
# <li><a onclick="setSearchBox('2100','countycodecommon')">부산</a></li>
# <li><a onclick="setSearchBox('2200','countycodecommon')">대구</a></li>
# <li><a onclick="setSearchBox('2401','countycodecommon')">광주</a></li>
# <li><a onclick="setSearchBox('2501','countycodecommon')">대전</a></li>
# </ul>
# <input id="countycodecommon" name="countycodecommon" type="hidden" value=""/>
# </div>
# <div class="smart_list searchCommArea" id="H">
# <ul class="list_ty1 ss2_ns" id="ulitemcategorycodecommon">
# <li class="on"><a onclick="setSearchBox('100','itemcategorycodecommon')">식량작물</a></li>
# <li><a onclick="setSearchBox('200','itemcategorycodecommon')">채소류</a></li>
# <li><a onclick="setSearchBox('300','itemcategorycodecommon')">특용작물</a></li>
# <li><a onclick="setSearchBox('400','itemcategorycodecommon')">과일류</a></li>
# <li id="H2" style="display:none;"><a onclick="setSearchBox('500','itemcategorycodecommon')">축산물</a></li>
# <li id="H3"><a onclick="setSearchBox('600','itemcategorycodecommon')">수산물</a></li>
# </ul>
# <input id="itemcategorycodecommon" name="itemcategorycodecommon" type="hidden" value="100"/>
# </div>
# <div class="smart_list searchCommArea" id="I">
# <ul class="list_ty1 ss3_ns" id="ulitemcodecommon">
# <li class="on"><a onclick="setSearchBox('111','itemcodecommon')">쌀</a></li>
# <li><a onclick="setSearchBox('112','itemcodecommon')">찹쌀</a></li>
# <li><a onclick="setSearchBox('141','itemcodecommon')">콩</a></li>
# <li><a onclick="setSearchBox('142','itemcodecommon')">팥</a></li>
# <li><a onclick="setSearchBox('143','itemcodecommon')">녹두</a></li>
# <li><a onclick="setSearchBox('144','itemcodecommon')">메밀</a></li>
# <li><a onclick="setSearchBox('151','itemcodecommon')">고구마</a></li>
# <li><a onclick="setSearchBox('152','itemcodecommon')">감자</a></li>
# </ul>
# <input id="itemcodecommon" name="itemcodecommon" type="hidden" value="111"/>
# </div>
# <div class="smart_list searchCommArea" id="J">
# <ul class="list_ty1 ss4_ns" id="ulkindcodecommon">
# <li class="on"><a onclick="setSearchBox('','kindcodecommon')">전체</a></li>
# <li><a onclick="setSearchBox('01','kindcodecommon')">일반계</a></li>
# <li><a onclick="setSearchBox('05','kindcodecommon')">햇일반계</a></li>
# </ul>
# <input id="kindcodecommon" name="kindcodecommon" type="hidden" value=""/>
# </div>
# <div class="smart_list searchCommArea" id="K">
# <ul class="list_ty3 ss5_ns" id="ulgraderankcommon">
# <li class="on"><a onclick="setSearchBox('','graderankcommon')">전체</a></li>
# <li><a onclick="setSearchBox('1','graderankcommon')">상품</a></li>
# <li><a onclick="setSearchBox('2','graderankcommon')">중품</a></li>
# </ul>
# <input id="graderankcommon" name="graderankcommon" type="hidden" value="0"/>
# <a class="btn_kg" id="convert_kg_of_common" onclick="setSearchBox('kg','convert_kg_yncommon')">kg 단위환산</a>
# <input id="convert_kg_yncommon" name="convert_kg_yncommon" type="hidden" value="N"/>
# </div>
# <div class="smart_list searchCommArea" id="L">
# <ul class="list_ty3 ss5_ns" id="ulproductrankcodecommon">
# <li class="on"><a onclick="setSearchBox('07','productrankcodecommon')">유기농</a></li>
# <li><a onclick="setSearchBox('08','productrankcodecommon')">무농약</a></li>
# <li><a onclick="setSearchBox('09','productrankcodecommon')">저농약</a></li>
# </ul>
# <input id="productrankcodecommon" name="productrankcodecommon" type="hidden" value="07"/>
# <input id="rankcommon" name="rankcommon" type="hidden" value="N"/>
# </div>
# <a class="btn_smart_start" onclick="goSearchCommon();" title="조회하기">조<br/>회<br/>하<br/>기</a>
# <input id="searchCommType" name="searchCommType" type="hidden" value="A"/>
# <input id="searchCommUrl" name="searchCommUrl" type="hidden" value="/customer/price/wholesale/item.do?action=priceinfo"/>
# <input id="productclscodecommon" name="productclscodecommon" type="hidden" value="02"/>
# </section>
# <!-- //검색세부항목 선택 -->
# </section>
# </section>
# <section class="gnbArea">
# <div class="wrap_comn">
# <a class="logo" href="/customer/main/main.do"><h1 class="hideTxt">aT kamis</h1></a>
# <div class="gnb">
# <ul>
# <li data-tab="gnb01">
# <a href="/customer/price/wholesale/item.do">가격정보</a>
# <div class="gnb_sub" id="gnb01">
# <div class="wrap_comn">
# <dl class="gnb0101" style="margin-right:41px;">
# <dt style="padding-right:20px;">도매가격<span style="font-size:12px;">(중도매인 판매가격)</span></dt>
# <dd class="current"><a href="/customer/price/wholesale/item.do">품목별</a></dd>
# <dd><a href="/customer/price/wholesale/period.do">기간별</a></dd>
# <dd><a href="/customer/price/wholesale/catalogue.do">부류별</a></dd>
# </dl>
# <dl class="gnb0106" style="margin-right:0px;">
# <dt>농산물 소매가격</dt>
# <dd><a href="/customer/price/agricultureRetail/item.do">품목별</a></dd>
# <dd><a href="/customer/price/agricultureRetail/period.do">기간별</a></dd>
# <dd><a href="/customer/price/agricultureRetail/catalogue.do">부류별</a></dd>
# <dd><a href="/customer/price/agricultureRetail/bizcondition/period.do">시장별</a></dd>
# </dl>
# <dl class="gnb0107" style="margin-right:0px;">
# <dt>수산물 소매가격</dt>
# <dd><a href="/customer/price/fisheriesRetail/item.do">품목별</a></dd>
# <dd><a href="/customer/price/fisheriesRetail/period.do">기간별</a></dd>
# <dd><a href="/customer/price/fisheriesRetail/catalogue.do">부류별</a></dd>
# <dd><a href="/customer/price/fisheriesRetail/bizcondition/period.do">시장별</a></dd>
# <dd><a href="/customer/price/fisheriesRetail/old/item.do">과거 가격자료 (~'22.7.)</a></dd>
# </dl>
# <dl class="gnb0108" style="margin-right:0px;">
# <dt>축산물 소매가격<span style="font-size:12px;">(축평원)</span></dt>
# <dd><a href="/customer/price/livestockRetail/period.do">기간별가격</a></dd>
# <dd><a href="/customer/price/livestockRetail/state.do">지역별평균가격</a></dd>
# <dd><a href="/customer/price/livestockRetail/bizcon.do">업태별가격정보</a></dd>
# <dd><a href="/customer/price/livestockRetail/old/item.do">과거 가격자료 (~'22.3.)</a></dd>
# </dl>
# <dl class="gnb0104" style="margin-right:0px;">
# <dt>가격정보 조사요령</dt>
# <dd><a href="/customer/price/knowhow/knowhow.do">조사개요</a></dd>
# <dd><a href="/customer/price/knowhow/knowhow.do?action=policyList">조사 및 분산체계</a></dd>
# <dd><a href="/customer/price/knowhow/knowhow.do?action=itemList">조사대상 품목</a></dd>
# <dd><a href="/customer/price/knowhow/knowhow.do?action=areaList">조사주기 및 지역</a></dd>
# <dd><a href="/customer/price/knowhow/knowhow.do?action=methodList">조사방법</a></dd>
# </dl>
# <dl class="gnb0105 last" style="margin-right:268px;">
# <dt>부가정보</dt>
# <dd><a href="/customer/price/wholesale/garak.do">주요 농산물 일일도매가격</a></dd>
# <dd><a href="/customer/price/ssm/item.do">ssm·sm 소매가격</a></dd>
# <dd><a href="/customer/price/process/item.do">가공식품 소매가격</a></dd>
# <dd><a href="/customer/price/franchise.do">외식 프랜차이즈 가격 동향</a></dd>
# <dd><a href="/customer/price/online/item.do">온라인 가격조사</a></dd>
# <!-- <dd><a href="/customer/price/sanji/item.do">산지가격</a></dd>
# 									<dd><a href="/customer/price/auctioning/item.do">경락가격</a></dd> -->
# <!-- <dd><a href="/customer/price/statistics.do">가격통계</a></dd> -->
# </dl>
# </div>
# </div> <!--//gnb_sub -->
# </li>
# <li data-tab="gnb02">
# <a href="/customer/trend/trade/daily.do">동향/전망</a>
# <div class="gnb_sub" id="gnb02">
# <div class="wrap_comn">
# <dl class="gnb0201" style="margin-right:30px;">
# <dt>거래동향</dt>
# <dd><a href="/customer/trend/trade/daily.do">일일동향</a></dd>
# <dd><a href="/customer/trend/trade/weekly.do">주간동향</a></dd>
# <dd><a href="/customer/trend/trade/monthly.do">월간동향</a></dd>
# </dl>
# <dl class="gnb0202" style="margin-right:30px;">
# <dt><a href="/customer/trend/product/product.do">제철 농수산물</a></dt>
# </dl>
# <dl class="gnb0203" style="margin-right:30px;">
# <dt><a href="/customer/trend/peakseason_info/peakseason_info.do">성수기정보</a></dt>
# </dl>
# <dl class="gnb0204" style="margin-right:30px;">
# <dt><a href="/customer/trend/foreign_info/foreign_info.do">농산물 해외수입정보</a></dt>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb03">
# <a href="/customer/archive/archive.do?action=summary">식재료 아카이브</a>
# <div class="gnb_sub" id="gnb03">
# <div class="wrap_comn">
# <!-- <dl class="gnb0301">
# 									<dt><a href="/customer/archive/archive.do?action=summary">식재료아카이브 소개</a></dt>
# 								</dl> -->
# <dl class="gnb0302">
# <dt><a href="/customer/archive/archive.do?action=summary">식재료 아카이브</a></dt>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb04">
# <a href="/customer/trend/economic/economic.do">알뜰장보기</a>
# <div class="gnb_sub" id="gnb04">
# <div class="wrap_comn">
# <dl class="gnb0401">
# <dt><a href="/customer/trend/economic/economic.do">주간알뜰장보기</a></dt>
# </dl>
# <dl class="gnb0402">
# <dt><a href="/customer/trend/economic/interest.do">업종별 관심품목</a></dt>
# </dl>
# <dl class="gnb0403">
# <dt><a href="/customer/trend/economic/howmuch.do">물가정보 방송인터뷰</a></dt>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb05">
# <a href="/customer/circulation/domestic/cost.do">유통실태</a>
# <div class="gnb_sub" id="gnb05">
# <div class="wrap_comn">
# <dl class="gnb0501">
# <dt>국내유통실태</dt>
# <dd><a href="/customer/circulation/domestic/cost.do">연도별 유통비용</a></dd>
# <dd><a href="/customer/circulation/domestic/product.do">품목별 유통비용</a></dd>
# <dd><a href="/customer/circulation/domestic/analysis.do">종합분석</a></dd>
# <dd><a href="/customer/circulation/domestic/item.do">품목별 유통실태</a></dd>
# <dd><a href="/customer/circulation/domestic/eco.do">친환경 유통실태</a></dd>
# <dd><a href="/customer/circulation/domestic/other.do">기타 유통실태</a></dd>
# </dl>
# <dl class="gnb0502">
# <dt><a href="/customer/circulation/overseas/overseas.do">해외유통실태</a></dt>
# </dl>
# <dl class="gnb0503">
# <dt><a href="/customer/circulation/spend/spend.do">소비실태</a></dt>
# </dl>
# <dl class="gnb0504">
# <dt>농산물 표준규격</dt>
# <dd><a href="/customer/circulation/standard/standard_shipment.do">표준규격출하율</a></dd>
# <dd><a href="/customer/circulation/standard/packaging_rate.do">포장화율</a></dd>
# </dl>
# <dl class="gnb0505" style="margin-right:0;">
# <dt>실태조사요령</dt>
# <dd><a href="/customer/circulation/distribution/state.do">유통실태조사</a></dd>
# <dd><a href="/customer/circulation/distribution/cost.do">물류비산정</a></dd>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb06">
# <a href="/customer/price/eco/summary.do">친환경농산물 유통정보</a>
# <div class="gnb_sub" id="gnb06">
# <div class="wrap_comn">
# <dl class="gnb0601">
# <dt>친환경농산물 개요</dt>
# <dd><a href="/customer/price/eco/summary.do">제도개요</a></dd>
# </dl>
# <dl class="gnb0602">
# <dt>소매가격정보</dt>
# <dd><a href="/customer/price/nature/knowhow.do?action=itemList">조사개요</a></dd>
# <dd><a href="/customer/price/nature/market.do">판매장유형별</a></dd>
# <dd><a href="/customer/price/nature/item.do">품목별</a></dd>
# <dd><a href="/customer/price/nature/period.do">기간별</a></dd>
# <dd><a href="/customer/price/nature/catalogue.do">부류별</a></dd>
# <!-- <dd><a href="#">인증별</a></dd> -->
# <dd><a href="/customer/price/eco/item.do">과거 가격자료 ('05~'20.3.)</a></dd>
# </dl>
# <dl class="gnb0603">
# <dt>조사보고서</dt>
# <dd><a href="/customer/nature/domestic.do">친환경농산물 유통실태조사</a></dd>
# <dd><a href="/customer/nature/agriculture.do">친환경농업 소득조사</a></dd>
# <dd><a href="/customer/nature/schoolfood.do">학교급식 현황조사</a></dd>
# <dd><a href="/customer/nature/market.do">판매장 현황조사</a></dd>
# <dd><a href="/customer/nature/customer.do">소비자 태도조사</a></dd>
# <dd><a href="/customer/nature/overseas.do">해외유통실태조사</a></dd>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb07">
# <a href="/customer/circulation/other/other.do">자료실</a>
# <div class="gnb_sub" id="gnb07">
# <div class="wrap_comn">
# <dl class="gnb0701">
# <dt><a href="/customer/circulation/other/other.do">일반자료실</a></dt>
# </dl>
# <dl class="gnb0702">
# <dt><a href="/customer/inform/news/news.do">유통뉴스</a></dt>
# </dl>
# <dl class="gnb0703">
# <dt><a href="/customer/inform/commonsense/eat.do">소비자상식</a></dt>
# <!-- <dd><a href="/customer/inform/commonsense/eat.do">먹거리</a></dd>
# 									<dd><a href="/customer/inform/commonsense/life.do">생활</a></dd>
# 									<dd><a href="/customer/inform/commonsense/health.do">건강</a></dd> -->
# </dl>
# <dl class="gnb0704">
# <dt>Open-API</dt>
# <dd><a href="/customer/reference/openapi_list.do">Open-API 이용안내</a></dd>
# <dd><a href="/customer/reference/openapi_write.do">Open-API 이용신청</a></dd>
# </dl>
# </div>
# </div>
# </li>
# <li data-tab="gnb08">
# <a href="/customer/inform/about/about.do">고객센터</a>
# <div class="gnb_sub" id="gnb08">
# <div class="wrap_comn">
# <dl class="gnb0801">
# <dt><a href="/customer/inform/about/about.do">KAMIS 소개</a></dt>
# </dl>
# <dl class="gnb0802">
# <dt><a href="/customer/inform/notice/notice.do">공지사항</a></dt>
# </dl>
# <dl class="gnb0803">
# <dt><a href="/customer/square/counsel/counsel.do">묻고답하기</a></dt>
# </dl>
# <!-- <dl class="gnb0804">
# 									<dt><a href="/customer/square/forum/forum.do">전문가포럼</a></dt>
# 								</dl> -->
# <dl class="gnb0805">
# <dt><a href="/customer/square/counsel/faq.do">자주묻는 질문</a></dt>
# </dl>
# <!-- 								<dl class="gnb0806">
# 									<dt><a href="/customer/square/participation/survey.do">설문참여</a></dt>
# 								</dl> -->
# <dl class="gnb0807">
# <dt><a href="/customer/inform/about/about.do?action=contact">찾아오시는 길</a></dt>
# </dl>
# </div>
# </div>
# </li>
# <li class="li_srch"><a class="ico srch" href="#" onclick="javascript:fnSearch();"><span class="hideTxt">검색</span></a></li>
# </ul>
# </div> <!--//gnb -->
# </div> <!--//wrap_comn -->
# </section> <!--//gnbArea -->
# </header>
# <div class="wrap">
# <!-- 		<div id="popupLayer522" class="popup_box" style="position: absolute; z-index: 400; width: 510px; display:none; margin-left:360px;">
# 				<ul>
# 					<li class="contents popup_background2 img" style="height:500px;">
# 						<a href="/customer/inform/notice/notice.do?action=detail&brdctsno=431938&pagenum=1&search_option=&search_keyword=&">
# 						<a href="https://www.kamis.or.kr/customer/inform/notice/notice.do?action=detail&brdctsno=431938&pagenum=1&search_option=&search_keyword=&">
# 							<img style="width:500px;" src="/images/customer/popup/20230428_popup.png" alt="5월1일 근로자의날">
# 						</a>
# 					</li>
# 					<li class="footer">
# 						<label
# 						 for="todayOpenNone1">
# 						<input type="checkbox" id="todayOpenNone1" name="todayOpenNone1" onclick="javascript:atPopup.setPopupCookie('popupLayer522');" value="Y">
# 						오늘 하루 열지 않기
# 						</label>
# 						<span style="/* line-height:10px; margin-top:-20px; */cursor : pointer;">
# 						<a href="#" onclick="javascript:$('#popupLayer522').hide();">Close</a></span>
# 					</li>
# 				</ul>
# 			</div> -->
# <section class="bnArea">
# <a href="https://m.kamis.or.kr:4434/mobile/app/index.do" target="_blank">
# <div class="wrap_comn">
# <span class="tit_sub">농수산물 유통정보의 중심</span>
# <b class="tit">KAMIS 농산물 유통정보 모바일 홈페이지 바로가기</b>
# <!-- 					<b class="tit">KAMIS 농산물 유통정보 모바일 홈페이지 바로가기</b></a> -->
# <div style="text-align:right; float:right; right:144px; position:relative;">
# <br/><span style="font-size:18px; font-family:'NotoKrR', '나눔고딕', 'NanumGothic', 'nng', 'nngb'">모바일 페이지 준비를 위한 APP 서비스 종료(6.16)</span>
# </div>
# <p class="tit_desc">농축수산물의 유통과 관련된 다양한 정보를 신속, 편리하게 제공하여 정보수요자의 유통에 관한 이해증진과 원활한 정보이용을 지원합니다.	</p>
# </div> <!--//wrap_comn -->
# </a>
# </section> <!--//bnArea -->
# <div class="contArea">
# <section class="wrap_comn">
# <div class="tbl_comn fl_l w_half tblArea wholesaleArea">
# <div class="titArea type_bd_none">
# <h2 class="tit">도매 가격<span class="tit_desc">(중도매인 판매가격)</span><span style="float:right;font-size:15px;margin-top:10px;">상품,원</span></h2>
# </div>
# <div class="tabList">
# <ul class="tab uifix">
# <li class="current" data-tab="tab_tbl01"><h3 class="tab_tit">식량작물</h3></li>
# <li data-tab="tab_tbl02"><h3 class="tab_tit">채소류</h3></li>
# <li data-tab="tab_tbl03"><h3 class="tab_tit">특용작물</h3></li>
# <li data-tab="tab_tbl04"><h3 class="tab_tit">과일류</h3></li>
# <li data-tab="tab_tbl06"><h3 class="tab_tit">수산물</h3></li>
# </ul> <!--//tab -->
# </div> <!--//tabList -->
# <div class="tabArea current" id="tab_tbl01">
# <table class="type_default scrolltbody">
# <colgroup>
# <col style="width:auto;"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">품목</th>
# <th scope="col">단위</th>
# <th scope="col">가격(08.07)</th>
# <th scope="col">등락률</th>
# <th scope="col">전일</th>
# <th scope="col">1개월전</th>
# <th scope="col">1년전</th>
# </tr>
# </thead>
# <tbody>
# <tr onclick="changeGraphWholesaleView('1', '2023-08-07', '쌀/20kg', '20kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														쌀/20kg
#
# 												</td>
# <td>20kg</td>
# <td style="text-align:right;">49,100</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													49,100
#
# 												</td>
# <td style="text-align:right;">
# 													47,512
#
# 												</td>
# <td style="text-align:right;">
# 													46,875
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('5', '2023-08-07', '찹쌀/일반계', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														찹쌀/일반계
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">100,700</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													100,700
#
# 												</td>
# <td style="text-align:right;">
# 													100,180
#
# 												</td>
# <td style="text-align:right;">
# 													107,750
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('8', '2023-08-07', '콩/흰 콩(국산)', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														콩/흰 콩(국산)
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">212,400</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													212,400
#
# 												</td>
# <td style="text-align:right;">
# 													212,280
#
# 												</td>
# <td style="text-align:right;">
# 													239,000
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('12', '2023-08-07', '콩/흰 콩(수입)', '35kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														콩/흰 콩(수입)
#
# 												</td>
# <td>35kg</td>
# <td style="text-align:right;">125,400</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													125,400
#
# 												</td>
# <td style="text-align:right;">
# 													125,400
#
# 												</td>
# <td style="text-align:right;">
# 													132,000
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('13', '2023-08-07', '팥/붉은 팥(국산)', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														팥/붉은 팥(국산)
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">422,200</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													422,200
#
# 												</td>
# <td style="text-align:right;">
# 													418,880
#
# 												</td>
# <td style="text-align:right;">
# 													372,600
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('15', '2023-08-07', '팥/붉은 팥(수입)', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														팥/붉은 팥(수입)
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">272,200</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													272,200
#
# 												</td>
# <td style="text-align:right;">
# 													272,400
#
# 												</td>
# <td style="text-align:right;">
# 													267,600
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('16', '2023-08-07', '녹두/국산', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														녹두/국산
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">502,500</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													502,500
#
# 												</td>
# <td style="text-align:right;">
# 													502,500
#
# 												</td>
# <td style="text-align:right;">
# 													702,938
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('18', '2023-08-07', '녹두/수입', '40kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														녹두/수입
#
# 												</td>
# <td>40kg</td>
# <td style="text-align:right;">223,400</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													223,400
#
# 												</td>
# <td style="text-align:right;">
# 													223,400
#
# 												</td>
# <td style="text-align:right;">
# 													225,000
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('19', '2023-08-07', '메밀/메밀(수입)', '1kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														메밀/메밀(수입)
#
# 												</td>
# <td>1kg</td>
# <td style="text-align:right;">4,375</td>
# <td>
#
#
#
# 															-
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													4,375
#
# 												</td>
# <td style="text-align:right;">
# 													4,375
#
# 												</td>
# <td style="text-align:right;">
# 													4,700
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('20', '2023-08-07', '고구마/밤', '10kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														고구마/밤
#
# 												</td>
# <td>10kg</td>
# <td style="text-align:right;">43,300</td>
# <td>
# <i class="ico arrow up"></i>
# 															    5.8%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													40,940
#
# 												</td>
# <td style="text-align:right;">
# 													37,240
#
# 												</td>
# <td style="text-align:right;">
# 													29,620
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('24', '2023-08-07', '감자/수미(노지)', '20kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														감자/수미(노지)
#
# 												</td>
# <td>20kg</td>
# <td style="text-align:right;">39,920</td>
# <td>
# <i class="ico arrow up"></i>
# 															    0.6%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													39,700
#
# 												</td>
# <td style="text-align:right;">
# 													37,292
#
# 												</td>
# <td style="text-align:right;">
# 													43,795
#
# 												</td>
# </tr>
# </tbody>
# </table>
# </div> <!--//tab_tbl01 -->
# <div class="tabArea" id="tab_tbl02">
# <table class="type_default scrolltbody">
# <colgroup>
# <col style="width:auto;"/>
# </colgroup>
# <thead>
# <tr>
# <th scope="col">품목</th>
# <th scope="col">단위</th>
# <th scope="col">가격(08.07)</th>
# <th scope="col">등락률</th>
# <th scope="col">전일</th>
# <th scope="col">1개월전</th>
# <th scope="col">1년전</th>
# </tr>
# </thead>
# <tbody>
# <tr onclick="changeGraphWholesaleView('30', '2023-08-07', '배추/여름(고랭지)', '10kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														배추/여름(고랭지)
#
# 												</td>
# <td>10kg</td>
# <td style="text-align:right;">22,080</td>
# <td>
# <i class="ico arrow up"></i>
# 															    9.1%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													20,240
#
# 												</td>
# <td style="text-align:right;">
#
# 													-
# 												</td>
# <td style="text-align:right;">
# 													19,855
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('36', '2023-08-07', '양배추/양배추', '8kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														양배추
#
#
# 												</td>
# <td>8kg</td>
# <td style="text-align:right;">14,680</td>
# <td>
# <i class="ico arrow up"></i>
# 															    4.4%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													14,060
#
# 												</td>
# <td style="text-align:right;">
# 													7,267
#
# 												</td>
# <td style="text-align:right;">
# 													10,963
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('2237', '2023-08-07', '알배기배추/알배기배추', '8kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														알배기배추
#
#
# 												</td>
# <td>8kg</td>
# <td style="text-align:right;">38,800</td>
# <td>
# <i class="ico arrow up"></i>
# 															    4.0%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													37,320
#
# 												</td>
# <td style="text-align:right;">
# 													15,056
#
# 												</td>
# <td style="text-align:right;">
#
# 													-
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('2239', '2023-08-07', '브로콜리/브로콜리(국산)', '8kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														브로콜리/브로콜리(국산)
#
# 												</td>
# <td>8kg</td>
# <td style="text-align:right;">50,860</td>
# <td>
# <i class="ico arrow up"></i>
# 															    7.2%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													47,460
#
# 												</td>
# <td style="text-align:right;">
# 													37,092
#
# 												</td>
# <td style="text-align:right;">
#
# 													-
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('38', '2023-08-07', '시금치/시금치', '4kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														시금치
#
#
# 												</td>
# <td>4kg</td>
# <td style="text-align:right;">57,760</td>
# <td>
# <i class="ico arrow down"></i>
# 															    4.0%
#
#
# 												</td>
# <td style="text-align:right;">
# 													60,140
#
# 												</td>
# <td style="text-align:right;">
# 													34,112
#
# 												</td>
# <td style="text-align:right;">
# 													41,765
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('40', '2023-08-07', '상추/적', '4kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														상추/적
#
# 												</td>
# <td>4kg</td>
# <td style="text-align:right;">55,440</td>
# <td>
# <i class="ico arrow down"></i>
# 															   13.6%
#
#
# 												</td>
# <td style="text-align:right;">
# 													64,140
#
# 												</td>
# <td style="text-align:right;">
# 													40,396
#
# 												</td>
# <td style="text-align:right;">
# 													38,405
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('42', '2023-08-07', '상추/청', '4kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														상추/청
#
# 												</td>
# <td>4kg</td>
# <td style="text-align:right;">55,160</td>
# <td>
# <i class="ico arrow down"></i>
# 															    4.1%
#
#
# 												</td>
# <td style="text-align:right;">
# 													57,540
#
# 												</td>
# <td style="text-align:right;">
# 													42,204
#
# 												</td>
# <td style="text-align:right;">
# 													39,925
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('44', '2023-08-07', '얼갈이배추/얼갈이배추', '4kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														얼갈이배추
#
#
# 												</td>
# <td>4kg</td>
# <td style="text-align:right;">10,806</td>
# <td>
# <i class="ico arrow down"></i>
# 															    6.1%
#
#
# 												</td>
# <td style="text-align:right;">
# 													11,512
#
# 												</td>
# <td style="text-align:right;">
# 													9,371
#
# 												</td>
# <td style="text-align:right;">
# 													9,339
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('46', '2023-08-07', '수박/수박', '1개');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														수박
#
#
# 												</td>
# <td>1개</td>
# <td style="text-align:right;">30,380</td>
# <td>
# <i class="ico arrow down"></i>
# 															    4.2%
#
#
# 												</td>
# <td style="text-align:right;">
# 													31,720
#
# 												</td>
# <td style="text-align:right;">
# 													22,572
#
# 												</td>
# <td style="text-align:right;">
# 													25,610
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('48', '2023-08-07', '참외/참외', '10kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														참외
#
#
# 												</td>
# <td>10kg</td>
# <td style="text-align:right;">68,200</td>
# <td>
# <i class="ico arrow up"></i>
# 															    2.0%
#
#
#
#
# 												</td>
# <td style="text-align:right;">
# 													66,860
#
# 												</td>
# <td style="text-align:right;">
# 													35,104
#
# 												</td>
# <td style="text-align:right;">
# 													44,963
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('50', '2023-08-07', '오이/가시계통', '10kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														오이/가시계통
#
# 												</td>
# <td>10kg</td>
# <td style="text-align:right;">25,500</td>
# <td>
# <i class="ico arrow down"></i>
# 															    3.8%
#
#
# 												</td>
# <td style="text-align:right;">
# 													26,500
#
# 												</td>
# <td style="text-align:right;">
# 													27,550
#
# 												</td>
# <td style="text-align:right;">
# 													25,463
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('52', '2023-08-07', '오이/다다기계통', '100개');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														오이/다다기계통
#
# 												</td>
# <td>100개</td>
# <td style="text-align:right;">58,500</td>
# <td>
# <i class="ico arrow down"></i>
# 															    7.9%
#
#
# 												</td>
# <td style="text-align:right;">
# 													63,500
#
# 												</td>
# <td style="text-align:right;">
# 													65,615
#
# 												</td>
# <td style="text-align:right;">
# 													77,050
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('54', '2023-08-07', '오이/취청', '50개');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														오이/취청
#
# 												</td>
# <td>50개</td>
# <td style="text-align:right;">26,867</td>
# <td>
# <i class="ico arrow down"></i>
# 															    8.9%
#
#
# 												</td>
# <td style="text-align:right;">
# 													29,500
#
# 												</td>
# <td style="text-align:right;">
# 													30,227
#
# 												</td>
# <td style="text-align:right;">
# 													27,142
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('56', '2023-08-07', '호박/애호박', '20개');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														호박/애호박
#
# 												</td>
# <td>20개</td>
# <td style="text-align:right;">23,200</td>
# <td>
# <i class="ico arrow down"></i>
# 															   22.9%
#
#
# 												</td>
# <td style="text-align:right;">
# 													30,100
#
# 												</td>
# <td style="text-align:right;">
# 													16,892
#
# 												</td>
# <td style="text-align:right;">
# 													25,215
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('58', '2023-08-07', '호박/쥬키니', '10kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
#
# 														호박/쥬키니
#
# 												</td>
# <td>10kg</td>
# <td style="text-align:right;">23,500</td>
# <td>
# <i class="ico arrow down"></i>
# 															   19.0%
#
#
# 												</td>
# <td style="text-align:right;">
# 													29,020
#
# 												</td>
# <td style="text-align:right;">
# 													9,521
#
# 												</td>
# <td style="text-align:right;">
# 													18,480
#
# 												</td>
# </tr>
# <tr onclick="changeGraphWholesaleView('60', '2023-08-07', '토마토/토마토', '5kg');" style="cursor:pointer;">
# <td style="text-align:left; padding-left:10px;">
#
# 														토마토
#
#
# 												</td>
# <td>5kg</td>
# <td style="text-align:right;">16,760</td>
# <td>
# <i class="ico arrow up"></i>
# 															    5.1%
#
#
#
#
# ...
# </div>
# </li>
# <li>
# <a class="uifix" href="/customer/inform/notice/notice.do?action=detail&amp;brdctsno=432021">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2023년 하반기 농식품마케팅대학 교육생 모집 안내</span>
# </div>
# <div class="fl_r">
# <span class="date">06.02</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/inform/notice/notice.do?action=detail&amp;brdctsno=431928">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">KAMIS 모바일 APP 서비스 중단 안내('23.6.16~)</span>
# </div>
# <div class="fl_r">
# <span class="date">04.25</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/inform/notice/notice.do?action=detail&amp;brdctsno=431789">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2023년 쌀가루(가루쌀) 제품개발 지원사업 사업자 모집공고</span>
# </div>
# <div class="fl_r">
# <span class="date">01.18</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/inform/notice/notice.do?action=detail&amp;brdctsno=431758">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2022년 KAMIS 활용사례 공모전 수상자 발표</span>
# </div>
# <div class="fl_r">
# <span class="date">12.28</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/inform/notice/notice.do?action=detail&amp;brdctsno=431746">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">KAMIS 서버 정비 안내('22.12.26 18:00-21:00)</span>
# </div>
# <div class="fl_r">
# <span class="date">12.26</span>
# </div>
# </a>
# </li>
# </ul>
# </div>
# <!--//notice tabArea -->
# <!--//csbg tabArea -->
# <div class="tabArea uifix" id="distnews">
# <ul>
# <li class="first uifix">
# <div class="txtArea">
# <span class="tit"><a href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432133">14개 주요 농축산물 주간 가격동향(7월 넷째주)</a></span>
# <p class="tit_desc">
#
#
#
# 															14개 주요 농축산물 주간 가격동향(7.24~7.29) 자료입니다.
#
#
# 												</p>
# </div>
# <div class="fl_r">
# <span class="date">08.01</span>
# </div>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432132">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">농수축산물 주간거래동향(7.31~8.5)</span>
# </div>
# <div class="fl_r">
# <span class="date">08.01</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432119">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">14개 주요 농축산물 주간 가격동향(7월 셋째주)</span>
# </div>
# <div class="fl_r">
# <span class="date">07.25</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432118">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">농수축산물 주간거래동향(7.24~7.29)</span>
# </div>
# <div class="fl_r">
# <span class="date">07.25</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432106">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">14개 주요 농축산물 주간 가격동향(7월 둘째주)</span>
# </div>
# <div class="fl_r">
# <span class="date">07.18</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/trade/weekly.do?action=detail&amp;brdctsno=432105">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">농수축산물 주간거래동향(7.17~7.22)</span>
# </div>
# <div class="fl_r">
# <span class="date">07.18</span>
# </div>
# </a>
# </li>
# </ul>
# </div> <!--//distnews tabArea -->
# <div class="tabArea uifix" id="peak">
# <ul>
# <li class="first uifix">
# <div class="txtArea">
# <span class="tit"><a href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=432127">7월 집밥 식재료 구입비용 전년 대비 4.1% 저렴</a></span>
# <p class="tit_desc">
#
#
#
#
# 													  		7월 집밥 식재료 구입비용 전년 대비 4.1% 저렴
# - 제철 농수산물을 활용한 4인 가족의 세끼 집밥 비용...
#
#
#
# 												</p>
# </div>
# <div class="fl_r">
# <span class="date">07.28</span>
# </div>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=432060">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">6월 집밥 식재료 구입비용 전년 대비 5.2% 저렴</span>
# </div>
# <div class="fl_r">
# <span class="date">06.30</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=432009">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">5월 집밥 식재료 구입비용 전년 대비 8.4% 저렴</span>
# </div>
# <div class="fl_r">
# <span class="date">05.27</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=431788">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">[2023년 설 보도자료(D-5)] 설 차례상 차림 비용 전주대비 하락 안정세</span>
# </div>
# <div class="fl_r">
# <span class="date">01.18</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=431779">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">[2023년 설 보도자료(D-12)]  설 차례상 차림 비용 전년과 비슷한 31만원 선</span>
# </div>
# <div class="fl_r">
# <span class="date">01.12</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/trend/peakseason_info/peakseason_info.do?action=detail&amp;brdctsno=431712">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">[2022년 김장비용 4차 보도자료] 12월 초 김장비용 하락 안정세 지속</span>
# </div>
# <div class="fl_r">
# <span class="date">12.06</span>
# </div>
# </a>
# </li>
# </ul>
# </div> <!--//peak tabArea -->
# <div class="tabArea uifix" id="dataroom">
# <ul>
# <li class="first uifix">
# <div class="txtArea">
# <span class="tit"><a href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=432017">농축산물 유통정보 조사요령 개정사항 안내</a></span>
# </div>
# <div class="fl_r">
# <span class="date">06.01</span>
# </div>
# </li>
# <li>
# <a class="uifix" href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=431930">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">KAMIS 모바일 APP 서비스 중단 안내('23.6.16~)</span>
# </div>
# <div class="fl_r">
# <span class="date">04.25</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=431707">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2022년 KAMIS 활용사례 공모전 공고(~12.19)</span>
# </div>
# <div class="fl_r">
# <span class="date">11.30</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=431680">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2022년 KAMIS 홈페이지 이용자 만족도 온라인 설문조사 참여 요청('22.11.16~)</span>
# </div>
# <div class="fl_r">
# <span class="date">11.16</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=431556">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">태풍 '힌남노' 북상 대비 대응요령 콘텐츠</span>
# </div>
# <div class="fl_r">
# <span class="date">09.05</span>
# </div>
# </a>
# </li>
# <li>
# <a class="uifix" href="/customer/circulation/other/other.do?action=detail&amp;brdctsno=431425">
# <div class="txtArea">
# <span class="tit_cate"></span>
# <span class="tit">2022년 aT국민참여혁신단 모집공고문</span>
# </div>
# <div class="fl_r">
# <span class="date">06.16</span>
# </div>
# </a>
# </li>
# </ul>
# </div> <!--//dataroom tabArea -->
# </div> <!--//newsArea -->
# <div class="popupArea fl_r w_half">
# <div class="titArea">
# <h2 class="tit">팝업존</h2>
# </div> <!--//titArea -->
# <div class="uifix">
# <div class="popupZoneArea">
# <ul>
# <li><a href="https://blog.naver.com/PostList.nhn?blogId=gr22nade&amp;from=postList&amp;categoryNo=82&amp;parentCategoryNo=82#" target="_self" title="주간 장바구니 물가, 제철 농수산물 정보"><img src="/customer/board/board_file.do?action=image&amp;brdno=51&amp;brdctsno=431565&amp;brdctsfileno=17662"/></a></li>
# <li><a href="https://www.instagram.com/p/CuEJYZyJyMN/?utm_source=ig_web_copy_link&amp;igshid=MzRlODBiNWFlZA==" target="_blank" title="복숭아 제철 투어"><img src="/customer/board/board_file.do?action=image&amp;brdno=51&amp;brdctsno=431955&amp;brdctsfileno=17659"/></a></li>
# </ul>
# </div>
# </div> <!--//uifix -->
# <!--
# 						<div class="uifix">
# 							<div class="popbn left">
# 								<div class="titArea">
# 									<span class="tit_desc">2018년도  aT KAMIS</span>
# 									<span class="tit">농약허용물질목록<br />관리제도 자료실</span>
# 								</div> //titArea
#
# 								<div class="btnArea">
# 									<a target="_blank" href="http://www.okdab.kr/pls/board/listBoard.do?bbsId=BBS_ID0000000086" class="btn">자세히보기</a>
# 								</div>
# 							</div>
# 							<div class="popbn right">
# 								<div class="titArea">
# 									<span class="tit_desc">2018년도  aT KAMIS</span>
# 									<span class="tit">지역별 각양각색 김치와<br />찰떡궁합 음식 즐기기</span>
# 								</div> //titArea
#
# 								<div class="btnArea">
# 									<a target="_blank" href="https://blog.naver.com/PostList.nhn?blogId=gr22nade&from=postList&categoryNo=82&parentCategoryNo=82#" class="btn">자세히보기</a>
# 								</div>
# 							</div>
# 						</div>
# 						-->
# </div> <!--//popupArea -->
# </section> <!--//wrap_comn -->
# <section class="wrap_comn">
# <div class="footbnArea uifix">
# <ul>
# <li><a href="http://www.at.or.kr/" target="_blank" title="aT한국농수산식품유통공사"><img alt="aT한국농수산식품유통공사 배너이미지" src="/common/img/main_foot_bn1.png"/></a></li>
# <li><a href="http://yfmc.at.or.kr" target="_blank" title="aT화훼공판장"><img alt="aT화훼공판장 배너이미지" src="/common/img/main_foot_bn2.png"/></a></li>
# <li><a href="http://www.eat.co.kr/attach/cyber/index.htm" target="_blank" title="농수산물 사이버거래소"><img alt="농수산물 사이버거래소 배너이미지" src="/common/img/main_foot_bn3.png"/></a></li>
# <li><a href="http://www.kati.net/index.do" target="_blank" title="농식품 수출정보"><img alt="농식품 수출정보 배너이미지" src="/common/img/main_foot_bn4.png"/></a></li>
# <li><a href="http://www.price.go.kr/" target="_blank" title="참가격 한국소비자원"><img alt="참가격 한국소비자원 배너이미지" src="/common/img/main_foot_bn5.png"/></a></li>
# <li><a href="http://www.baroinfo.com" target="_blank" title="바로정보"><img alt="바로정보 배너이미지" src="/common/img/main_foot_bn6.png"/></a></li>
# <li><a href="http://www.nongnet.or.kr" target="_blank" title="농넷"><img alt="농넷 배너이미지" src="/common/img/main_foot_bn7.png"/></a></li>
# </ul>
# </div> <!--//footbnArea -->
# </section>
# </div> <!--//contArea -->
# </div> <!--//wrap -->
# <script type="text/javascript">
# function goFamilySite(obj){
# 	var url = $( obj ).val();
# 	if(url != ""){
# 		window.open(url);
# 	}
# }
# function goRelOffice(obj){
# 	var url = $( obj ).val();
# 	if(url != ""){
# 		window.open(url);
# 	}
# }
# </script>
# <footer>
# <div class="wrap_comn">
# <div class="guideArea uifix">
# <a class="logo" href="#"><span class="hideTxt">aTkamis</span></a>
# <div class="guideDesc">
# <ul class="guideMenu">
# <li><a href="/customer/information_services/about.do?action=about5" title="이용안내">이용안내</a></li>
# <li><a href="http://www.at.or.kr/html/member/at_acount_2.html" onclick="window.open(this.href, '', 'width=865px, height=680px, resizable=no, location=no, scrollbars=yes'); return false;" style="color:#646565;" target="_blank" title="개인정보처리방침"><strong>개인정보처리방침</strong></a></li>
# <li><a href="/customer/information_services/viewer/viewer.do" title="뷰어다운로드">뷰어다운로드</a></li>
# <li><a href="http://www.at.or.kr/html/member/at_acount_3.html" onclick="window.open(this.href, '', 'width=865px, height=551px, resizable=no, location=no, scrollbars=yes'); return false;" target="_blank" title="저작권보호정책">저작권보호정책</a></li>
# <li><a href="/customer/information_services/email_reject/email_reject.do" title="전자우편주소수집거부">전자우편주소수집거부</a></li>
# <li><a href="/customer/inform/about/about.do?action=contact" title="찾아오시는길">오시는길</a></li>
# <li><a href="/customer/information_services/about.do?action=about6" title="사이트맵">사이트맵</a></li>
# </ul> <!--//guideMenu -->
# <ul class="guideInfo">
# <li>[58326] 전라남도 나주시 문화로 227 한국농수산식품유통공사</li>
# <li>전화 : 061-931-1114</li>
# <li>팩스 : 061-804-4535</li>
# <li>E-mail : kamis@at.or.kr</li>
# <li>COPYRIGHT @2012 by Korea Agro-Fisheries &amp; Food Trade Corporation ALL RIGHTS RESERVED.</li>
# </ul> <!--//guideInfo -->
# </div> <!--//guideDesc -->
# <a class="gcsico" href="#" onclick="javascript:window.open('/common/img/gcs_good.jpg','굿컨텐츠서비스 인증','width=512px,height=715px,scrollbars=no');return false;"><span class="hideTxt">굿컨텐츠서비스</span></a>
# </div> <!--//guideArea -->
# <div class="directArea uifix">
# <div class="snsArea fl_l">
# <ul>
# <li><a href="javascript:shareSNS('facebook');" title="페이스북"><i class="ico sns fb"></i><span class="hideTxt">페이스북 바로가기</span></a></li>
# <li><a href="javascript:shareSNS('twitter');" title="트위터"><i class="ico sns twt"></i><span class="hideTxt">트위터 바로가기</span></a></li>
# </ul>
# </div> <!--//snsArea -->
# <div class="linkArea fl_r">
# <select id="footerFamilySite" name="footerFamilySite" onchange="javascript:goFamilySite(this);">
# <option>패밀리 사이트</option>
# <option value="http://www.at.or.kr">aT통합홈페이지</option>
# <option value="http://www.kati.net/">KATI 농식품수출정보</option>
# <option value="https://www.atfis.or.kr/home/index.do">FIS식품산업통계정보</option>
# <option value="http://www.atfis.or.kr/fip/front/index.do">한국외식산업정보포털(The외식)</option>
# <option value="http://atess.at.or.kr/">수출지원시스템</option>
# <option value="http://global.at.or.kr/">aT수출업체종합지원시스템</option>
# <option value="http://www.foodbiz.or.kr/">식품기업지원관리시스템</option>
# <option value="http://www.agrotrade.net/">AgroTrade</option>
# <!-- <option value="http://whimori.at.or.kr">Whimori(휘모리 브랜드)</option> -->
# <option value="http://www.eat.co.kr/attach/cyber/index.htm">aT농식품거래소</option>
# <option value="http://www.baroinfo.com">바로정보</option>
# <option value="http://www.atbid.co.kr/">비축농산물 전자입찰시스템</option>
# <option value="https://www.agromarket.kr">정가수의매매 예약정보제공 시스템</option>
# <option value="http://atcenter.at.or.kr">aTCenter</option>
# <option value="http://edu.at.or.kr">aT농식품유통교육원</option>
# <option value="http://yfmc.at.or.kr">aT화훼공판장</option>
# <option value="http://thesool.com">더 술</option>
# <option value="https://bms.at.or.kr/index.do">BMS</option>
# <!-- <option value="http://www.foodbiz.or.kr/">aT농수산식품기업지원센터</option>
# 					<option value="http://www.kati.net/">KATI</option>
# 					<option value="http://www.agrotrade.net/">Agro Trade</option>
# 					<option value="http://atcenter.at.or.kr">aT센터</option>
# 					<option value="http://whimori.at.or.kr">휘모리</option>
# 					 option value="http://forestproduct.at.or.kr">한국의 임산물</option
# 					<option value="http://atess.at.or.kr/">수출지원시스템</option>
# 					<option value="http://global.at.or.kr/">수출업체정보</option>
# 					<option value="http://yfmc.at.or.kr">aT화훼공판장</option>
# 					<option value="http://edu.at.or.kr">aT농식품유통교육원</option>
# 					<option value="http://www.eat.co.kr/attach/cyber/index.htm">사이버거래소</option>
# 					<option value="http://www.atbid.co.kr/">전자입찰</option> -->
# </select>
# <select id="footerRelOffice" name="footerRelOffice" onchange="javascript:goRelOffice(this);">
# <option>유관기관</option>
# <!-- <option value="http://www.maf.go.kr/">농림축산식품부</option> -->
# <option value="http://www.mafra.go.kr/">농림축산식품부</option>
# <option value="http://www.naqs.go.kr/">국립농산물품질관리원</option>
# <option value="http://www.naas.go.kr/">농촌진흥청 국립농업과학원</option>
# <option value="http://www.qia.go.kr/">농림축산검역본부</option>
# <option value="http://www.seed.go.kr/">국립종자원</option>
# <option value="http://www.kma.go.kr/">기상청</option>
# <option value="http://www.ipet.re.kr/">농림수산식품기술기획평가원</option>
# <option value="http://www.epis.or.kr/">농림수산식품교육문화정보원</option>
# <option value="http://www.ati.go.kr/">농식품공무원교육원</option>
# <!-- <option value="http://www.agrihrd.or.kr/">농업인재개발원</option> -->
# <option value="http://www.rda.go.kr/">농촌진흥청</option>
# <option value="http://www.nonghyup.com/">농협</option>
# <option value="http://www.forest.go.kr">산림청</option>
# <option value="http://www.suhyup.co.kr/">수협</option>
# <option value="http://www.ekr.or.kr">한국농어촌공사</option>
# <option value="https://www.af.ac.kr">한국농수산대학</option>
# <option value="http://www.krei.re.kr/">한국농촌경제연구원</option>
# <option value="http://www.kfri.re.kr/">한국식품연구원</option>
# <option value="http://www.sonosa.or.kr/">남북교류협력지원협회</option>
# <!-- <option value="http://market.affis.net/">도매시장통합홈페이지</option> -->
# </select>
# </div> <!--//linkArea -->
# </div> <!--//directArea -->
# </div> <!--//wrap_comn -->
# </footer>
# </body>
# </html>

# %%
gamja =soup.select('#tab_tbl01 > table > tbody > tr:nth-child(11) > td:nth-child(5)')
gamja2 = gamja[0].text

# %%
gamja_text = gamja2.strip().replace(',', '')
gamja_price = int(gamja_text)

# %%
gamja_price
# Out:
# 39700
